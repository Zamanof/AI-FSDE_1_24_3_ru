# %%
import torch
import torch.nn as nn

# %%
linear = nn.Linear(in_features=3, out_features=2)
X = torch.tensor([1.0, 2.0, 4.0])
y = linear(X)
print(f"X input {X}")
print(f"y output {y}")
print(f"y.shape {y.shape}")

print(f"W: {linear.weight}")
print(f"b: {linear.bias}")
# Out:
# X input tensor([1., 2., 4.])
# y output tensor([ 0.3874, -1.1373], grad_fn=<ViewBackward0>)
# y.shape torch.Size([2])
# W: Parameter containing:
# tensor([[-0.5104, -0.5492,  0.4855],
#         [ 0.3630, -0.2855, -0.3220]], requires_grad=True)
# b: Parameter containing:
# tensor([0.0544, 0.3586], requires_grad=True)

# %% [markdown]
# - Функции активаций
#     - nn.ReLU
#     - nn.Sigmoid
#     - nn.Tanh
#
#
# - Функции потерь
#     - nn.MSELoss
#     - nn.CrossEntropyLoss
#     - nn.BCEWithLogisticLoss
#
#
# - nn.Sequential
#
#
# - nn.Module
