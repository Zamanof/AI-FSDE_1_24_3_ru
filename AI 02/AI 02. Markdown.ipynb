# %% [markdown]
# # Заголовок 1 уровня
# ## Заголовок 2 уровня
# ### Заголовок 3 уровня
# #### Заголовок 4 уровня

# %% [markdown]
# **жирный текст**
# *курсив*
# ~~зачёркнутый текст~~
# `код или команда`

# %% [markdown]
# ```python
# print("Пример кода")
# ```

# %% [markdown]
# | Показатель | Значение |
# |-------------|-----------|
# | Среднее     | 15.2      |
# | Максимум    | 27        |
# | Минимум     | 3         |

# %% [markdown]
# Формула в строке: $E = mc^2$
#
# Блок формулы:
# $$
# \sigma = \sqrt{\frac{1}{N}\sum_{i=1}^{N}(x_i - \mu)^2}
# $$

# %% [markdown]
# 1. Item1
# 2. Item2
# 3. Item3

# %% [markdown]
# - item 1
# - item 2
#     - subitem1
#     - subitem2

# %% [markdown]
# > Это цитата

# %% [markdown]
# [Открыть Numpy Documentation](https://numpy.org/)
# ![Numpy logo](https://numpy.org/images/logo.svg)

# %% [markdown]
# | Показатель |   Значение | Коментарии|
# |:-------------|:-----------:|----:|
# | Среднее     |       15.2 | Lorem|
# | Максимум    |         27 |Ipsum dolor sit amet|
# | Минимум     |          3 | Ipsum|

# %% [markdown]
# <p style="color: blue; font-size:50px;">
#    Этот текст синий и крупный
# </p>

# %% [markdown]
# <p align="center">
# <b>Выравнивание по центру и жирный текст</b>
# </p>

# %% [markdown]
# <span style="color:orange">оранжевый</span>,
# <span style="color:green">зелёный</span>,
# <span style="color:red; font-weight:bold;">красный жирный</span>

# %% [markdown]
# <div style="border-left: 5px solid #3498db; padding: 10px; background: blue;">
# <b>💡 Подсказка:</b> Используйте функцию <code>np.mean()</code>, чтобы вычислить среднее значение массива.
# </div>
